# %%
import pandas as pd
import matplotlib.pyplot as plt

mlb_data = pd.read_csv('mlb_team_stats_24.csv')

# %%
mlb_data.head(10)
# Out:
#                      Tm  #Bat  BatAge   R/G   G    PA    AB    R    H   2B  \
# 0  Arizona Diamondbacks    42    28.9  4.72  79  2994  2663  373  668  132
# 1        Atlanta Braves    44    28.7  4.43  76  2844  2578  337  631  149
# 2     Baltimore Orioles    42    27.1  5.23  79  3025  2745  413  697  141
# 3        Boston Red Sox    42    27.3  4.67  80  3063  2741  374  694  145
# 4          Chicago Cubs    42    28.2  4.14  80  3001  2649  331  607  113
# 5     Chicago White Sox    48    28.6  3.04  81  2922  2663  246  582  117
# 6       Cincinnati Reds    38    27.4  4.27  79  2897  2566  337  587  119
# 7   Cleveland Guardians    37    26.2  5.09  77  2880  2562  392  631  131
# 8      Colorado Rockies    40    27.9  4.28  79  2972  2695  338  671  141
# 9        Detroit Tigers    36    27.3  4.11  79  2943  2660  325  617  118
#
#    ...    PO    A   E  DP   Fld%  Rtot  Rtot/yr  Rdrs  Rdrs/yr  Rgood
# 0  ...  2094  730  34  76  0.988    13        2    15        4      2
# ...

# %%
mlb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 80 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tm       31 non-null     object
#  1   #Bat     32 non-null     int64
#  2   BatAge   32 non-null     float64
#  3   R/G      32 non-null     float64
#  4   G        32 non-null     int64
#  5   PA       32 non-null     int64
#  6   AB       32 non-null     int64
#  7   R        32 non-null     int64
#  8   H        32 non-null     int64
#  9   2B       32 non-null     int64
#  10  3B       32 non-null     int64
#  11  HR       32 non-null     int64
#  12  RBI      32 non-null     int64
#  13  SB       32 non-null     int64
#  14  CS       32 non-null     int64
#  15  BB       32 non-null     int64
#  16  SO       32 non-null     int64
#  17  BA       32 non-null     float64
#  18  OBP      32 non-null     float64
#  19  SLG      32 non-null     float64
#  20  OPS      32 non-null     float64
# ...

# %%
mlb_data.describe()
# Out:
#               #Bat     BatAge        R/G            G            PA  \
# count    32.000000  32.000000  32.000000    32.000000     32.000000
# mean     78.093750  28.150000   4.361562   151.468750   5680.062500
# std     206.398981   0.955797   0.488455   407.393603  15275.672939
# min      36.000000  26.200000   3.040000    76.000000   2844.000000
# 25%      39.000000  27.475000   4.087500    79.000000   2927.250000
# 50%      42.000000  28.200000   4.360000    79.000000   2978.500000
# 75%      44.250000  28.750000   4.702500    80.250000   3027.750000
# max    1209.000000  30.300000   5.230000  2384.000000  89391.000000
#
#                  AB             R             H           2B          3B  ...  \
# count     32.000000     32.000000     32.000000    32.000000   32.000000  ...
# mean    5090.187500    660.437500   1231.125000   239.312500   22.625000  ...
# std    13689.316492   1776.593459   3311.127697   643.685028   60.974744  ...
# ...

# %%
mlb_data['BA'].hist(bins=20, edgecolor='black')
plt.xlabel('Batting Average')
plt.ylabel('Number of Teams')
plt.title('Distribution of Batting Average Across Teams')
plt.grid(True)
plt.show()

# %%
correlation_matrix = mlb_data.corr()
plt.imshow(correlation_matrix, cmap='coolwarm')
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=45)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.title('Correlation Matrix of Team Statistics')
plt.grid(False)
plt.show()
# Out:
# /var/folders/0c/4yxzntyn3ls7qgzfjx6l6pxm0000gn/T/ipykernel_21986/2551078621.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = mlb_data.corr()

# %%
winning_teams = data[data['W'] > data['L']]
losing_teams = data[data['W'] < data['L']]

# Compare batting averages using boxplots
plt.boxplot([winning_teams['BA'], losing_teams['BA']], notch=True, vert=True, patch_artist=True)
plt.xticks([1, 2], ['Winning Teams', 'Losing Teams'])
plt.ylabel('Batting Average')
plt.title('Batting Average Distribution by Wins/Losses')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
mlb_data.columns
# Out:
# Index(['Tm', '#Bat', 'BatAge', 'R/G', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B',
#        'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+',
#        'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB', 'LOB', '#P', 'PAge', 'RA/G', 'W',
#        'L', 'W-L%', 'ERA', 'GS', 'GF', 'CG', 'tSho', 'cSho', 'SV', 'IP', 'H.1',
#        'R.1', 'ER', 'HR.1', 'BB.1', 'IBB.1', 'SO.1', 'HBP.1', 'BK', 'WP', 'BF',
#        'ERA+', 'FIP', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9', 'SO/W', 'LOB.1',
#        '#Fld', 'RA/G.1', 'DefEff', 'GS.1', 'CG.1', 'Inn', 'Ch', 'PO', 'A', 'E',
#        'DP', 'Fld%', 'Rtot', 'Rtot/yr', 'Rdrs', 'Rdrs/yr', 'Rgood'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Define features (independent variables) and target variable (dependent variable)
features = ['BA', 'OBP', 'OPS'] 
target = 'SLG'

# %%
# Split data into training and testing sets (e.g., 80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(mlb_data[features], mlb_data[target], test_size=0.2, random_state=42)

# %%
# Create a linear regression model
model = LinearRegression()

# %%
# Train the model on the training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the testing set
y_pred = model.predict(X_test)

# %%
# Evaluate model performance (mean squared error)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 5.657167598600855e-07
